# %% [markdown]
# ### Dataset description and problem definition

# %% [markdown]
# ##### This is dataset contians some informations for 13260 of food items with some features like (Calories, Total Fat, Saturated Fat, Monounsaturated Fat, Trans Fat, Cholesterol, Sodium, Sugars, Vitamin A, Vitamin C, Calcium, Iron) and a class label to represent the food type.
# ##### The main goal is making models to predict the food type after balance the data to can get better results.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("food_items.csv")

# %%
df
# Out:
#        Calories  Total Fat  Saturated Fat  Monounsaturated Fat  \
# 0         149.0          0            0.0                  0.0
# 1         123.0          0            0.0                  0.0
# 2         150.0          0            0.0                  0.0
# 3         110.0          0            0.0                  0.0
# 4         143.0          0            0.0                  0.0
# ...         ...        ...            ...                  ...
# 13255     140.0          5            1.0                  0.0
# 13256     130.0          4            0.5                  0.0
# 13257     140.0          3            0.0                  0.0
# 13258     140.0          3            0.5                  0.0
# 13259     120.0          4            0.5                  0.0
#
#        Polyunsaturated Fat  Trans Fat  Cholesterol  Sodium  \
# 0                      0.0        0.0            0     9.0
# 1                      0.0        0.0            0     5.0
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Descriptive statistics for numerical features

# %%
df.describe()
# Out:
#            Calories     Total Fat  Saturated Fat  Monounsaturated Fat  \
# count  13260.000000  13260.000000   13260.000000         13260.000000
# mean     133.861086      4.475264       1.450617             0.338069
# std       94.227650      5.386340       2.410318             1.345852
# min        0.000000      0.000000       0.000000             0.000000
# 25%       70.000000      0.000000       0.000000             0.000000
# 50%      120.000000      3.000000       0.500000             0.000000
# 75%      180.000000      7.000000       2.000000             0.000000
# max     2210.000000     43.000000      22.000000            40.000000
#
#        Polyunsaturated Fat     Trans Fat   Cholesterol        Sodium  \
# count         13260.000000  13260.000000  13260.000000  13260.000000
# mean              0.254660      0.047459      8.857692    241.867142
# std               2.230586      0.321402     20.976530    272.284363
# ...

# %% [markdown]
# #### Visualization to explore disributions and relationships

# %%
sns.pairplot(df,diag_kind='kde')

# %% [markdown]
# #### Correlation matrix of features

# %%
corr = df.drop(columns=['class'],axis=1).corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr,annot=True,cmap='coolwarm', square=True, fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# #### Box plots to check on outliers

# %%
X = df.drop(columns='class',axis=1)

# %%
plt.figure(figsize=(20, len(X.columns) * 4))
for i, col in enumerate(X.columns):
    plt.subplot(len(X.columns) // 3+1 , 3, i + 1)
    sns.boxplot(X[col])
    plt.title(f'Box plot of {col}')

plt.show()

# %% [markdown]
# #### Check on balance of data

# %%
df['class'].value_counts()
# Out:
# class
# 'In Moderation'    6649
# 'Less Often'       5621
# 'More Often'        990
# Name: count, dtype: int64

# %% [markdown]
# #### Identify Issues

# %% [markdown]
# All features contain outliers.\
# The distribution of all features is positively skewed.\
# The data is imbalance.

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# ##### Normalize the distribution of data

# %%
X = X.apply(lambda col : np.log1p(col))

# %% [markdown]
# ##### Encoding catigorical data

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df['class'])
y = pd.DataFrame({'class':y})

# %%
df = pd.concat([X,y],axis=1)

# %%
df['class'].value_counts()
# Out:
# class
# 0    6649
# 1    5621
# 2     990
# Name: count, dtype: int64

# %% [markdown]
# ##### Drop the outliers

# %%
for col in X.columns:
    Q1 = df[col].quantile(.25)
    Q3 = df[col].quantile(.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %%
df = df.reset_index().drop(columns=['index'],axis=1)

# %% [markdown]
# #### Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df[X.columns] = scaler.fit_transform(df[X.columns])

# %% [markdown]
# #### Drop duplicated data

# %%
df.duplicated().sum()
# Out:
# np.int64(951)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### Balance the data

# %%
X = df.drop(columns=['class'],axis=1)
y = df['class']

# %%
from imblearn.over_sampling import SMOTE

# %%
smote=SMOTE(random_state=42) 
X,y=smote.fit_resample(X,y)
# Out:
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
y.value_counts()
# Out:
# class
# 0    3575
# 1    3575
# 2    3575
# Name: count, dtype: int64

# %% [markdown]
# #### Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Modeling and Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, f1_score, classification_report, roc_auc_score, roc_curve

# %% [markdown]
# #### 1. Multinomial Logistic Regression

# %%
M = LogisticRegression(multi_class='multinomial',penalty=None,solver='saga')
M.fit(X_train, y_train)
# Out:
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(multi_class='multinomial', penalty=None, solver='saga')

# %%
y_pred_M = M.predict(X_test)

# %%
print(classification_report(y_test, y_pred_M, target_names=label_encoder.classes_))
# Out:
#                  precision    recall  f1-score   support
#
# 'In Moderation'       0.79      0.78      0.79      1080
#    'Less Often'       0.83      0.81      0.82      1100
#    'More Often'       0.94      0.99      0.96      1038
#
#        accuracy                           0.86      3218
#       macro avg       0.86      0.86      0.86      3218
#    weighted avg       0.85      0.86      0.85      3218

# %%
cm_M = confusion_matrix(y_test, y_pred_M)
sns.heatmap(cm_M, annot=True, cmap='Blues', fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# #### 2. Multinomial Lasso Logistic Regression

# %%
M_l1 = LogisticRegression(multi_class='multinomial',penalty='l1',solver='saga')
M_l1.fit(X_train, y_train)
# Out:
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(multi_class='multinomial', penalty='l1', solver='saga')

# %%
y_pred_Ml1 = M_l1.predict(X_test)

# %%
print(classification_report(y_test, y_pred_Ml1, target_names=label_encoder.classes_))
# Out:
#                  precision    recall  f1-score   support
#
# 'In Moderation'       0.79      0.78      0.78      1080
#    'Less Often'       0.83      0.81      0.82      1100
#    'More Often'       0.94      0.99      0.96      1038
#
#        accuracy                           0.85      3218
#       macro avg       0.85      0.86      0.85      3218
#    weighted avg       0.85      0.85      0.85      3218

# %%
cm_Ml1 = confusion_matrix(y_test, y_pred_Ml1)
sns.heatmap(cm_Ml1, annot=True, cmap='Blues', fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# #### 3. Multinomial Ridge Logistic Regression

# %%
M_l2 = LogisticRegression(multi_class='multinomial',penalty='l2',solver='saga')
M_l2.fit(X_train, y_train)
# Out:
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='multinomial', solver='saga')

# %%
y_pred_Ml2 = M_l2.predict(X_test)

# %%
print(classification_report(y_test, y_pred_Ml1, target_names=label_encoder.classes_))
# Out:
#                  precision    recall  f1-score   support
#
# 'In Moderation'       0.79      0.78      0.78      1080
#    'Less Often'       0.83      0.81      0.82      1100
#    'More Often'       0.94      0.99      0.96      1038
#
#        accuracy                           0.85      3218
#       macro avg       0.85      0.86      0.85      3218
#    weighted avg       0.85      0.85      0.85      3218

# %%
cm_Ml2 = confusion_matrix(y_test, y_pred_Ml2)
sns.heatmap(cm_Ml2, annot=True, cmap='Blues', fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# #### 4. Multinomial ElasticNet Logistic Regression

# %%
M_EN = LogisticRegression(multi_class='multinomial',penalty='elasticnet',solver='saga',l1_ratio=0.5)
M_EN.fit(X_train, y_train)
# Out:
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(l1_ratio=0.5, multi_class='multinomial',
#                    penalty='elasticnet', solver='saga')

# %%
y_pred_MEN = M_EN.predict(X_test)

# %%
print(classification_report(y_test, y_pred_MEN, target_names=label_encoder.classes_))
# Out:
#                  precision    recall  f1-score   support
#
# 'In Moderation'       0.78      0.76      0.77      1080
#    'Less Often'       0.83      0.79      0.81      1100
#    'More Often'       0.92      0.99      0.95      1038
#
#        accuracy                           0.84      3218
#       macro avg       0.84      0.85      0.84      3218
#    weighted avg       0.84      0.84      0.84      3218

# %%
cm_MEN = confusion_matrix(y_test, y_pred_MEN)
sns.heatmap(cm_MEN, annot=True, cmap='Blues', fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# #### 5. One vs Rest Logistic Regression

# %%
OVR = LogisticRegression(multi_class='ovr',solver='liblinear')
OVR.fit(X_train, y_train)
# Out:
# C:\Users\body2\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
y_pred_OVR = OVR.predict(X_test)

# %%
print(classification_report(y_test, y_pred_OVR, target_names=label_encoder.classes_))
# Out:
#                  precision    recall  f1-score   support
#
# 'In Moderation'       0.77      0.71      0.74      1080
#    'Less Often'       0.82      0.79      0.81      1100
#    'More Often'       0.88      0.99      0.93      1038
#
#        accuracy                           0.83      3218
#       macro avg       0.83      0.83      0.83      3218
#    weighted avg       0.83      0.83      0.83      3218

# %%
cm_OVR = confusion_matrix(y_test, y_pred_OVR)
sns.heatmap(cm_OVR, annot=True, cmap='Blues', fmt='d')
# Out:
# <Axes: >

# %% [markdown]
# ### Model Comparison and Interpretation

# %% [markdown]
# Multinomial strategy generally performed better than One_vs_Rest for this food classification task, as evidenced by higher accuracy and F1 scores.

# %% [markdown]
# #### How regularization affected model performance and generalization?

# %% [markdown]
# In this case regularization didn't make any improvment in accuracy or f1 score. \
# The regularized model get worse test metrics than multinomial without regularization.

# %% [markdown]
# #### How data balancing methods improved classification results.

# %% [markdown]
# Data balancing was the most thing made a good perfomance improvment .\
# It led to more uniform precision and recall across all food types.

# %% [markdown]
# ####  Justify the best-performing model

# %% [markdown]
# The best performing model is the multibomial logistic regression without regularization .\
# It get the best acccuracy and f1score
